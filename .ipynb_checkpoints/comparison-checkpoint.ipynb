# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

df = pd.read_csv('ebay.csv')  
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
plt.figure(figsize=(10, 6))

plt.plot(df.index, df['Ensemble_Mamba'], color='blue', label='Ensemble Mamba')
plt.plot(df.index, df['Mamba'], color='green', label='Mamba')
plt.plot(df.index, df['BH_Value'], color='red', label='BaH')

plt.xlabel('Day')
plt.ylabel('Capital ($)')
plt.title('Comparison of Buy & Hold, Mamba, and Ensemble Mamba Strategies on EBAY stock.')


plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=15))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

plt.xticks(rotation=45)
plt.xlim([df.index.min(), df.index.max()])
plt.legend()
plt.tight_layout()
plt.savefig('ebay.png', format='png', dpi=300)
plt.show()
