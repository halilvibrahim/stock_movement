# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import os
import math
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from mamba import *

# %%
stock_name = 'PEP'
df = yf.download(stock_name,
                 start='2016-06-01',
                 end='2019-01-26',
                 progress=False)
file_name = f'{stock_name}.csv'
df.to_csv(file_name)

# %%
df = pd.read_csv(file_name)
close_prices = df['Close']

# %%
print(close_prices.shape)
# Out:
# (668,)

# %%
plt.figure(figsize=(10, 6))
plt.plot(close_prices, label='Close Price')
plt.title('Stock Close Prices')
plt.xlabel('Day')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
pct_changes = close_prices.pct_change().dropna()*100

# %%
pct_changes = pct_changes.values.reshape(-1, 1)

# %%
plt.figure(figsize=(10, 5))
plt.plot(pct_changes, color='cyan', label='Percentage Changes %')
plt.title('', fontsize=16, fontweight='bold', color='white')
plt.xlabel('Days', fontsize=14, color='black')
plt.ylabel('Percentage Change', fontsize=14, color='black')
plt.legend(loc='upper left', fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray') 
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
pct_changes = scaler.fit_transform(pct_changes)

# %%
plt.figure(figsize=(10, 5))
plt.plot(pct_changes, color='cyan', label='Percentage Changes % (Z Score)')
plt.title('', fontsize=16, fontweight='bold', color='white')
plt.xlabel('Days', fontsize=14, color='black')
plt.ylabel('Percentage Change', fontsize=14, color='black')
plt.legend(loc='upper left', fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray') 
plt.show()

# %%
lower_bound = -3
upper_bound = 3
pct_changes = np.clip(pct_changes, lower_bound, upper_bound)
plt.figure(figsize=(10, 5))
plt.plot(pct_changes, color='cyan', label='Percentage Changes % (Z Score) (Outliers clipped)')
plt.title('', fontsize=16, fontweight='bold', color='white')
plt.xlabel('Days', fontsize=14, color='black')
plt.ylabel('Percentage Change %', fontsize=14, color='black')
plt.legend(loc='upper left', fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray')  
plt.show()

# %%
print(pct_changes.shape)
# Out:
# (667, 1)

# %%
def create_time_series_windows(dataset, time_step=1):
    features, labels = [], []
    for i in range(len(dataset)-time_step):
        historical_data = dataset[i:(i+time_step), 0]
        features.append(historical_data)
        labels.append(dataset[i + time_step, 0])
    return np.array(features), np.array(labels)

# %%
import itertools
from sklearn.metrics import f1_score
# Hiperparametre değerlerini tanımlayalım
hyperparams = {
    'time_step': [10, 20],
    'lr': [0.0001, 0.001],
    'num_epochs': [50, 100],
    'batch_size': [64, 32],
    'd_model': [64, 32],
    'd_state': [16, 8],
    'n_layers': [2, 3]
}

# Tüm kombinasyonları oluştur
param_combinations = list(itertools.product(*hyperparams.values()))
results = []

# %%
for i, params in enumerate(param_combinations):
    time_step, lr, num_epochs, batch_size, d_model, d_state, n_layers = params

    # Zaman serisi verisini yeniden oluştur
    X, y = create_time_series_windows(pct_changes, time_step)
    
    # Veriyi yeniden böl
    test_size = 120
    training_size = int(len(X) - test_size)
    X_train, X_test = X[0:training_size], X[training_size:len(X)]
    y_train, y_test = y[0:training_size], y[training_size:len(y)]

    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
    X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

    X_train = torch.FloatTensor(X_train)
    y_train = torch.FloatTensor(y_train)
    X_test = torch.FloatTensor(X_test)
    y_test = torch.FloatTensor(y_test)

    # Modeli yeniden tanımla
    config = MambaConfig(
        d_model=d_model,
        n_layers=n_layers,
        dt_rank='auto',
        d_state=d_state,
        expand_factor=2,
        d_conv=4,
        dt_min=0.001,
        dt_max=0.1,
        dt_init="random",
        dt_scale=1.0,
        bias=False,
        conv_bias=True,
        pscan=True
    )
    
    model = Mamba(config)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    # İlk ağırlıkları kaydet
    initial_weight_filename = f"initial_weights_model_{i}.pth"
    torch.save(model.state_dict(), initial_weight_filename)

    train_dataset = TensorDataset(X_train, y_train)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

    val_dataset = TensorDataset(X_test, y_test)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    
    # Eğitim döngüsü
    for epoch in range(num_epochs):
        model.train()
        for batch_x, batch_y in train_loader:
            batch_x, batch_y = batch_x.to(device), batch_y.to(device)
            optimizer.zero_grad()

            outputs = model(batch_x)
            last_outputs = outputs[:, -1, -1]

            loss = criterion(last_outputs, batch_y)
            loss.backward()
            optimizer.step()

    
    # Test aşaması
    model.eval()
    X_test_tensor = X_test.clone().detach().to(device).view(-1, time_step, 1)
    with torch.no_grad():
        y_test_pred = model(X_test_tensor)[:, -1, -1]

    y_test_pred = y_test_pred.cpu().numpy().reshape(-1, 1)
    y_test_pred = scaler.inverse_transform(y_test_pred)

    
    y_test_binary = np.where(y_test > 0, 1, 0)
    y_pred_binary = np.where(y_test_pred > 0, 1, 0)

    f1 = f1_score(y_test_binary, y_pred_binary)
    print(f"Model {i}: F1 Score = {f1:.2f}")
    results.append((params, f1, initial_weight_filename))
# Out:
# Model 0: F1 Score = 0.53
# Model 1: F1 Score = 0.54
# Model 2: F1 Score = 0.53
# Model 3: F1 Score = 0.52
# Model 4: F1 Score = 0.58
# Model 5: F1 Score = 0.57
# Model 6: F1 Score = 0.53
# Model 7: F1 Score = 0.57
# Model 8: F1 Score = 0.49
# Model 9: F1 Score = 0.49
# Model 10: F1 Score = 0.51
# Model 11: F1 Score = 0.56
# Model 12: F1 Score = 0.51
# Model 13: F1 Score = 0.56
# Model 14: F1 Score = 0.56
# Model 15: F1 Score = 0.57
# Model 16: F1 Score = 0.52
# Model 17: F1 Score = 0.50
# Model 18: F1 Score = 0.46
# Model 19: F1 Score = 0.57
# Model 20: F1 Score = 0.53
# Model 21: F1 Score = 0.50
# Model 22: F1 Score = 0.58
# Model 23: F1 Score = 0.55
# Model 24: F1 Score = 0.52
# Model 25: F1 Score = 0.49
# Model 26: F1 Score = 0.55
# Model 27: F1 Score = 0.54
# Model 28: F1 Score = 0.52
# Model 29: F1 Score = 0.43
# Model 30: F1 Score = 0.51
# Model 31: F1 Score = 0.56
# Model 32: F1 Score = 0.52
# Model 33: F1 Score = 0.52
# Model 34: F1 Score = 0.58
# Model 35: F1 Score = 0.49
# Model 36: F1 Score = 0.49
# Model 37: F1 Score = 0.46
# Model 38: F1 Score = 0.48
# Model 39: F1 Score = 0.50
# Model 40: F1 Score = 0.56
# Model 41: F1 Score = 0.55
# Model 42: F1 Score = 0.49
# Model 43: F1 Score = 0.51
# Model 44: F1 Score = 0.52
# Model 45: F1 Score = 0.49
# Model 46: F1 Score = 0.55
# Model 47: F1 Score = 0.46
# Model 48: F1 Score = 0.57
# Model 49: F1 Score = 0.58
# Model 50: F1 Score = 0.41
# Model 51: F1 Score = 0.47
# Model 52: F1 Score = 0.52
# Model 53: F1 Score = 0.46
# Model 54: F1 Score = 0.53
# Model 55: F1 Score = 0.53
# Model 56: F1 Score = 0.46
# Model 57: F1 Score = 0.51
# Model 58: F1 Score = 0.47
# Model 59: F1 Score = 0.50
# Model 60: F1 Score = 0.59
# Model 61: F1 Score = 0.56
# Model 62: F1 Score = 0.55
# Model 63: F1 Score = 0.51
# Model 64: F1 Score = 0.57
# Model 65: F1 Score = 0.52
# Model 66: F1 Score = 0.55
# Model 67: F1 Score = 0.54
# Model 68: F1 Score = 0.59
# Model 69: F1 Score = 0.60
# Model 70: F1 Score = 0.55
# Model 71: F1 Score = 0.63
# Model 72: F1 Score = 0.50
# Model 73: F1 Score = 0.52
# Model 74: F1 Score = 0.51
# Model 75: F1 Score = 0.49
# Model 76: F1 Score = 0.48
# Model 77: F1 Score = 0.49
# Model 78: F1 Score = 0.51
# Model 79: F1 Score = 0.60
# Model 80: F1 Score = 0.53
# Model 81: F1 Score = 0.47
# Model 82: F1 Score = 0.55
# Model 83: F1 Score = 0.48
# Model 84: F1 Score = 0.56
# Model 85: F1 Score = 0.57
# Model 86: F1 Score = 0.57
# Model 87: F1 Score = 0.56
# Model 88: F1 Score = 0.52
# Model 89: F1 Score = 0.49
# Model 90: F1 Score = 0.49
# Model 91: F1 Score = 0.45
# Model 92: F1 Score = 0.57
# Model 93: F1 Score = 0.54
# Model 94: F1 Score = 0.57
# Model 95: F1 Score = 0.51
# Model 96: F1 Score = 0.53
# Model 97: F1 Score = 0.54
# Model 98: F1 Score = 0.51
# Model 99: F1 Score = 0.50
# Model 100: F1 Score = 0.52
# Model 101: F1 Score = 0.51
# Model 102: F1 Score = 0.44
# Model 103: F1 Score = 0.54
# Model 104: F1 Score = 0.56
# Model 105: F1 Score = 0.53
# Model 106: F1 Score = 0.53
# Model 107: F1 Score = 0.56
# Model 108: F1 Score = 0.52
# Model 109: F1 Score = 0.48
# Model 110: F1 Score = 0.53
# Model 111: F1 Score = 0.48
# Model 112: F1 Score = 0.46
# Model 113: F1 Score = 0.52
# Model 114: F1 Score = 0.49
# Model 115: F1 Score = 0.52
# Model 116: F1 Score = 0.43
# Model 117: F1 Score = 0.51
# Model 118: F1 Score = 0.53
# Model 119: F1 Score = 0.42
# Model 120: F1 Score = 0.56
# Model 121: F1 Score = 0.54
# Model 122: F1 Score = 0.45
# Model 123: F1 Score = 0.48
# Model 124: F1 Score = 0.48
# Model 125: F1 Score = 0.51
# Model 126: F1 Score = 0.50
# Model 127: F1 Score = 0.53

# %%
print("Hiperparametre Sonuçları:")
print("---------------------------------")
for params, f1, weight_file in results:
    print(f"Params: {params}, F1 Score: {f1:.2f}, Initial Weights: {weight_file}")
# Out:
# Hiperparametre Sonuçları:
# ---------------------------------
# Params: (10, 0.0001, 50, 64, 64, 16, 2), F1 Score: 0.53, Initial Weights: initial_weights_model_0.pth
# Params: (10, 0.0001, 50, 64, 64, 16, 3), F1 Score: 0.54, Initial Weights: initial_weights_model_1.pth
# Params: (10, 0.0001, 50, 64, 64, 8, 2), F1 Score: 0.53, Initial Weights: initial_weights_model_2.pth
# Params: (10, 0.0001, 50, 64, 64, 8, 3), F1 Score: 0.52, Initial Weights: initial_weights_model_3.pth
# Params: (10, 0.0001, 50, 64, 32, 16, 2), F1 Score: 0.58, Initial Weights: initial_weights_model_4.pth
# Params: (10, 0.0001, 50, 64, 32, 16, 3), F1 Score: 0.57, Initial Weights: initial_weights_model_5.pth
# Params: (10, 0.0001, 50, 64, 32, 8, 2), F1 Score: 0.53, Initial Weights: initial_weights_model_6.pth
# Params: (10, 0.0001, 50, 64, 32, 8, 3), F1 Score: 0.57, Initial Weights: initial_weights_model_7.pth
# Params: (10, 0.0001, 50, 32, 64, 16, 2), F1 Score: 0.49, Initial Weights: initial_weights_model_8.pth
# Params: (10, 0.0001, 50, 32, 64, 16, 3), F1 Score: 0.49, Initial Weights: initial_weights_model_9.pth
# Params: (10, 0.0001, 50, 32, 64, 8, 2), F1 Score: 0.51, Initial Weights: initial_weights_model_10.pth
# Params: (10, 0.0001, 50, 32, 64, 8, 3), F1 Score: 0.56, Initial Weights: initial_weights_model_11.pth
# Params: (10, 0.0001, 50, 32, 32, 16, 2), F1 Score: 0.51, Initial Weights: initial_weights_model_12.pth
# Params: (10, 0.0001, 50, 32, 32, 16, 3), F1 Score: 0.56, Initial Weights: initial_weights_model_13.pth
# Params: (10, 0.0001, 50, 32, 32, 8, 2), F1 Score: 0.56, Initial Weights: initial_weights_model_14.pth
# Params: (10, 0.0001, 50, 32, 32, 8, 3), F1 Score: 0.57, Initial Weights: initial_weights_model_15.pth
# Params: (10, 0.0001, 100, 64, 64, 16, 2), F1 Score: 0.52, Initial Weights: initial_weights_model_16.pth
# Params: (10, 0.0001, 100, 64, 64, 16, 3), F1 Score: 0.50, Initial Weights: initial_weights_model_17.pth
# Params: (10, 0.0001, 100, 64, 64, 8, 2), F1 Score: 0.46, Initial Weights: initial_weights_model_18.pth
# Params: (10, 0.0001, 100, 64, 64, 8, 3), F1 Score: 0.57, Initial Weights: initial_weights_model_19.pth
# Params: (10, 0.0001, 100, 64, 32, 16, 2), F1 Score: 0.53, Initial Weights: initial_weights_model_20.pth
# Params: (10, 0.0001, 100, 64, 32, 16, 3), F1 Score: 0.50, Initial Weights: initial_weights_model_21.pth
# Params: (10, 0.0001, 100, 64, 32, 8, 2), F1 Score: 0.58, Initial Weights: initial_weights_model_22.pth
# Params: (10, 0.0001, 100, 64, 32, 8, 3), F1 Score: 0.55, Initial Weights: initial_weights_model_23.pth
# Params: (10, 0.0001, 100, 32, 64, 16, 2), F1 Score: 0.52, Initial Weights: initial_weights_model_24.pth
# Params: (10, 0.0001, 100, 32, 64, 16, 3), F1 Score: 0.49, Initial Weights: initial_weights_model_25.pth
# Params: (10, 0.0001, 100, 32, 64, 8, 2), F1 Score: 0.55, Initial Weights: initial_weights_model_26.pth
# Params: (10, 0.0001, 100, 32, 64, 8, 3), F1 Score: 0.54, Initial Weights: initial_weights_model_27.pth
# Params: (10, 0.0001, 100, 32, 32, 16, 2), F1 Score: 0.52, Initial Weights: initial_weights_model_28.pth
# Params: (10, 0.0001, 100, 32, 32, 16, 3), F1 Score: 0.43, Initial Weights: initial_weights_model_29.pth
# Params: (10, 0.0001, 100, 32, 32, 8, 2), F1 Score: 0.51, Initial Weights: initial_weights_model_30.pth
# Params: (10, 0.0001, 100, 32, 32, 8, 3), F1 Score: 0.56, Initial Weights: initial_weights_model_31.pth
# Params: (10, 0.001, 50, 64, 64, 16, 2), F1 Score: 0.52, Initial Weights: initial_weights_model_32.pth
# Params: (10, 0.001, 50, 64, 64, 16, 3), F1 Score: 0.52, Initial Weights: initial_weights_model_33.pth
# Params: (10, 0.001, 50, 64, 64, 8, 2), F1 Score: 0.58, Initial Weights: initial_weights_model_34.pth
# Params: (10, 0.001, 50, 64, 64, 8, 3), F1 Score: 0.49, Initial Weights: initial_weights_model_35.pth
# Params: (10, 0.001, 50, 64, 32, 16, 2), F1 Score: 0.49, Initial Weights: initial_weights_model_36.pth
# Params: (10, 0.001, 50, 64, 32, 16, 3), F1 Score: 0.46, Initial Weights: initial_weights_model_37.pth
# Params: (10, 0.001, 50, 64, 32, 8, 2), F1 Score: 0.48, Initial Weights: initial_weights_model_38.pth
# Params: (10, 0.001, 50, 64, 32, 8, 3), F1 Score: 0.50, Initial Weights: initial_weights_model_39.pth
# Params: (10, 0.001, 50, 32, 64, 16, 2), F1 Score: 0.56, Initial Weights: initial_weights_model_40.pth
# Params: (10, 0.001, 50, 32, 64, 16, 3), F1 Score: 0.55, Initial Weights: initial_weights_model_41.pth
# Params: (10, 0.001, 50, 32, 64, 8, 2), F1 Score: 0.49, Initial Weights: initial_weights_model_42.pth
# Params: (10, 0.001, 50, 32, 64, 8, 3), F1 Score: 0.51, Initial Weights: initial_weights_model_43.pth
# Params: (10, 0.001, 50, 32, 32, 16, 2), F1 Score: 0.52, Initial Weights: initial_weights_model_44.pth
# Params: (10, 0.001, 50, 32, 32, 16, 3), F1 Score: 0.49, Initial Weights: initial_weights_model_45.pth
# Params: (10, 0.001, 50, 32, 32, 8, 2), F1 Score: 0.55, Initial Weights: initial_weights_model_46.pth
# Params: (10, 0.001, 50, 32, 32, 8, 3), F1 Score: 0.46, Initial Weights: initial_weights_model_47.pth
# Params: (10, 0.001, 100, 64, 64, 16, 2), F1 Score: 0.57, Initial Weights: initial_weights_model_48.pth
# Params: (10, 0.001, 100, 64, 64, 16, 3), F1 Score: 0.58, Initial Weights: initial_weights_model_49.pth
# Params: (10, 0.001, 100, 64, 64, 8, 2), F1 Score: 0.41, Initial Weights: initial_weights_model_50.pth
# Params: (10, 0.001, 100, 64, 64, 8, 3), F1 Score: 0.47, Initial Weights: initial_weights_model_51.pth
# Params: (10, 0.001, 100, 64, 32, 16, 2), F1 Score: 0.52, Initial Weights: initial_weights_model_52.pth
# Params: (10, 0.001, 100, 64, 32, 16, 3), F1 Score: 0.46, Initial Weights: initial_weights_model_53.pth
# Params: (10, 0.001, 100, 64, 32, 8, 2), F1 Score: 0.53, Initial Weights: initial_weights_model_54.pth
# Params: (10, 0.001, 100, 64, 32, 8, 3), F1 Score: 0.53, Initial Weights: initial_weights_model_55.pth
# Params: (10, 0.001, 100, 32, 64, 16, 2), F1 Score: 0.46, Initial Weights: initial_weights_model_56.pth
# Params: (10, 0.001, 100, 32, 64, 16, 3), F1 Score: 0.51, Initial Weights: initial_weights_model_57.pth
# Params: (10, 0.001, 100, 32, 64, 8, 2), F1 Score: 0.47, Initial Weights: initial_weights_model_58.pth
# Params: (10, 0.001, 100, 32, 64, 8, 3), F1 Score: 0.50, Initial Weights: initial_weights_model_59.pth
# Params: (10, 0.001, 100, 32, 32, 16, 2), F1 Score: 0.59, Initial Weights: initial_weights_model_60.pth
# Params: (10, 0.001, 100, 32, 32, 16, 3), F1 Score: 0.56, Initial Weights: initial_weights_model_61.pth
# Params: (10, 0.001, 100, 32, 32, 8, 2), F1 Score: 0.55, Initial Weights: initial_weights_model_62.pth
# Params: (10, 0.001, 100, 32, 32, 8, 3), F1 Score: 0.51, Initial Weights: initial_weights_model_63.pth
# Params: (20, 0.0001, 50, 64, 64, 16, 2), F1 Score: 0.57, Initial Weights: initial_weights_model_64.pth
# Params: (20, 0.0001, 50, 64, 64, 16, 3), F1 Score: 0.52, Initial Weights: initial_weights_model_65.pth
# Params: (20, 0.0001, 50, 64, 64, 8, 2), F1 Score: 0.55, Initial Weights: initial_weights_model_66.pth
# Params: (20, 0.0001, 50, 64, 64, 8, 3), F1 Score: 0.54, Initial Weights: initial_weights_model_67.pth
# Params: (20, 0.0001, 50, 64, 32, 16, 2), F1 Score: 0.59, Initial Weights: initial_weights_model_68.pth
# Params: (20, 0.0001, 50, 64, 32, 16, 3), F1 Score: 0.60, Initial Weights: initial_weights_model_69.pth
# Params: (20, 0.0001, 50, 64, 32, 8, 2), F1 Score: 0.55, Initial Weights: initial_weights_model_70.pth
# Params: (20, 0.0001, 50, 64, 32, 8, 3), F1 Score: 0.63, Initial Weights: initial_weights_model_71.pth
# Params: (20, 0.0001, 50, 32, 64, 16, 2), F1 Score: 0.50, Initial Weights: initial_weights_model_72.pth
# Params: (20, 0.0001, 50, 32, 64, 16, 3), F1 Score: 0.52, Initial Weights: initial_weights_model_73.pth
# Params: (20, 0.0001, 50, 32, 64, 8, 2), F1 Score: 0.51, Initial Weights: initial_weights_model_74.pth
# Params: (20, 0.0001, 50, 32, 64, 8, 3), F1 Score: 0.49, Initial Weights: initial_weights_model_75.pth
# Params: (20, 0.0001, 50, 32, 32, 16, 2), F1 Score: 0.48, Initial Weights: initial_weights_model_76.pth
# Params: (20, 0.0001, 50, 32, 32, 16, 3), F1 Score: 0.49, Initial Weights: initial_weights_model_77.pth
# Params: (20, 0.0001, 50, 32, 32, 8, 2), F1 Score: 0.51, Initial Weights: initial_weights_model_78.pth
# Params: (20, 0.0001, 50, 32, 32, 8, 3), F1 Score: 0.60, Initial Weights: initial_weights_model_79.pth
# Params: (20, 0.0001, 100, 64, 64, 16, 2), F1 Score: 0.53, Initial Weights: initial_weights_model_80.pth
# Params: (20, 0.0001, 100, 64, 64, 16, 3), F1 Score: 0.47, Initial Weights: initial_weights_model_81.pth
# Params: (20, 0.0001, 100, 64, 64, 8, 2), F1 Score: 0.55, Initial Weights: initial_weights_model_82.pth
# Params: (20, 0.0001, 100, 64, 64, 8, 3), F1 Score: 0.48, Initial Weights: initial_weights_model_83.pth
# Params: (20, 0.0001, 100, 64, 32, 16, 2), F1 Score: 0.56, Initial Weights: initial_weights_model_84.pth
# Params: (20, 0.0001, 100, 64, 32, 16, 3), F1 Score: 0.57, Initial Weights: initial_weights_model_85.pth
# Params: (20, 0.0001, 100, 64, 32, 8, 2), F1 Score: 0.57, Initial Weights: initial_weights_model_86.pth
# Params: (20, 0.0001, 100, 64, 32, 8, 3), F1 Score: 0.56, Initial Weights: initial_weights_model_87.pth
# Params: (20, 0.0001, 100, 32, 64, 16, 2), F1 Score: 0.52, Initial Weights: initial_weights_model_88.pth
# Params: (20, 0.0001, 100, 32, 64, 16, 3), F1 Score: 0.49, Initial Weights: initial_weights_model_89.pth
# Params: (20, 0.0001, 100, 32, 64, 8, 2), F1 Score: 0.49, Initial Weights: initial_weights_model_90.pth
# Params: (20, 0.0001, 100, 32, 64, 8, 3), F1 Score: 0.45, Initial Weights: initial_weights_model_91.pth
# Params: (20, 0.0001, 100, 32, 32, 16, 2), F1 Score: 0.57, Initial Weights: initial_weights_model_92.pth
# Params: (20, 0.0001, 100, 32, 32, 16, 3), F1 Score: 0.54, Initial Weights: initial_weights_model_93.pth
# Params: (20, 0.0001, 100, 32, 32, 8, 2), F1 Score: 0.57, Initial Weights: initial_weights_model_94.pth
# Params: (20, 0.0001, 100, 32, 32, 8, 3), F1 Score: 0.51, Initial Weights: initial_weights_model_95.pth
# Params: (20, 0.001, 50, 64, 64, 16, 2), F1 Score: 0.53, Initial Weights: initial_weights_model_96.pth
# Params: (20, 0.001, 50, 64, 64, 16, 3), F1 Score: 0.54, Initial Weights: initial_weights_model_97.pth
# Params: (20, 0.001, 50, 64, 64, 8, 2), F1 Score: 0.51, Initial Weights: initial_weights_model_98.pth
# Params: (20, 0.001, 50, 64, 64, 8, 3), F1 Score: 0.50, Initial Weights: initial_weights_model_99.pth
# Params: (20, 0.001, 50, 64, 32, 16, 2), F1 Score: 0.52, Initial Weights: initial_weights_model_100.pth
# Params: (20, 0.001, 50, 64, 32, 16, 3), F1 Score: 0.51, Initial Weights: initial_weights_model_101.pth
# Params: (20, 0.001, 50, 64, 32, 8, 2), F1 Score: 0.44, Initial Weights: initial_weights_model_102.pth
# Params: (20, 0.001, 50, 64, 32, 8, 3), F1 Score: 0.54, Initial Weights: initial_weights_model_103.pth
# Params: (20, 0.001, 50, 32, 64, 16, 2), F1 Score: 0.56, Initial Weights: initial_weights_model_104.pth
# Params: (20, 0.001, 50, 32, 64, 16, 3), F1 Score: 0.53, Initial Weights: initial_weights_model_105.pth
# Params: (20, 0.001, 50, 32, 64, 8, 2), F1 Score: 0.53, Initial Weights: initial_weights_model_106.pth
# Params: (20, 0.001, 50, 32, 64, 8, 3), F1 Score: 0.56, Initial Weights: initial_weights_model_107.pth
# Params: (20, 0.001, 50, 32, 32, 16, 2), F1 Score: 0.52, Initial Weights: initial_weights_model_108.pth
# Params: (20, 0.001, 50, 32, 32, 16, 3), F1 Score: 0.48, Initial Weights: initial_weights_model_109.pth
# Params: (20, 0.001, 50, 32, 32, 8, 2), F1 Score: 0.53, Initial Weights: initial_weights_model_110.pth
# Params: (20, 0.001, 50, 32, 32, 8, 3), F1 Score: 0.48, Initial Weights: initial_weights_model_111.pth
# Params: (20, 0.001, 100, 64, 64, 16, 2), F1 Score: 0.46, Initial Weights: initial_weights_model_112.pth
# Params: (20, 0.001, 100, 64, 64, 16, 3), F1 Score: 0.52, Initial Weights: initial_weights_model_113.pth
# Params: (20, 0.001, 100, 64, 64, 8, 2), F1 Score: 0.49, Initial Weights: initial_weights_model_114.pth
# Params: (20, 0.001, 100, 64, 64, 8, 3), F1 Score: 0.52, Initial Weights: initial_weights_model_115.pth
# Params: (20, 0.001, 100, 64, 32, 16, 2), F1 Score: 0.43, Initial Weights: initial_weights_model_116.pth
# Params: (20, 0.001, 100, 64, 32, 16, 3), F1 Score: 0.51, Initial Weights: initial_weights_model_117.pth
# Params: (20, 0.001, 100, 64, 32, 8, 2), F1 Score: 0.53, Initial Weights: initial_weights_model_118.pth
# Params: (20, 0.001, 100, 64, 32, 8, 3), F1 Score: 0.42, Initial Weights: initial_weights_model_119.pth
# Params: (20, 0.001, 100, 32, 64, 16, 2), F1 Score: 0.56, Initial Weights: initial_weights_model_120.pth
# Params: (20, 0.001, 100, 32, 64, 16, 3), F1 Score: 0.54, Initial Weights: initial_weights_model_121.pth
# Params: (20, 0.001, 100, 32, 64, 8, 2), F1 Score: 0.45, Initial Weights: initial_weights_model_122.pth
# Params: (20, 0.001, 100, 32, 64, 8, 3), F1 Score: 0.48, Initial Weights: initial_weights_model_123.pth
# Params: (20, 0.001, 100, 32, 32, 16, 2), F1 Score: 0.48, Initial Weights: initial_weights_model_124.pth
# Params: (20, 0.001, 100, 32, 32, 16, 3), F1 Score: 0.51, Initial Weights: initial_weights_model_125.pth
# Params: (20, 0.001, 100, 32, 32, 8, 2), F1 Score: 0.50, Initial Weights: initial_weights_model_126.pth
# Params: (20, 0.001, 100, 32, 32, 8, 3), F1 Score: 0.53, Initial Weights: initial_weights_model_127.pth

# %%
import os
pid = os.getpid()
# !kill -9 $pid
